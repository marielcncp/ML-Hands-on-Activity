# %%
from preprocessing_functions import preprocess_dataset

# %%
X_train, X_test, y_train, y_test, tokenizer, encoder = preprocess_dataset(
    csv_path="ds.csv",
    vocab_size=10000,
    max_len=30
)
# Out:
# ⚠️ Warning: Some classes have <2 samples. Stratify disabled.

# %%
print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)

print("Classes:", encoder.classes_)
# Out:
# Train shape: (2783, 30)
# Test shape: (696, 30)
# Classes: ['negative' 'neutral' 'positive' "positive'"]
